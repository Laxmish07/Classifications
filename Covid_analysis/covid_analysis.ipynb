# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns


# Directory containing CSV files
directory = 'E:\CSU Work\Thesis and RA\datasets\datasets'

# Function to process a single CSV file
def process_csv(file_path):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path, skiprows=2, skipfooter=1,engine='python')
    print("Size of original Dataset of file :",filename,"is", df.shape)

    # Select columns with useful data
    df = df[['Year', '18-44 - Percentage', '45-64 - Percentage', '65-74 - Percentage', '75+ - Percentage']]
    print("\nColumn data :\n", df.head())

    # Separate data before and after 2018
    #Considering below 2019 as before covid and after 2018 as After covid
    before_2018 = df[df['Year'] <= 2018]
    after_2018 = df[df['Year'] > 2018]
    before_2018.set_index('Year', inplace=True)
    after_2018.set_index('Year', inplace=True)

    # Calculate percentage change for each age range
    def calculate_percentage_change(data):
        percent_change = {}
        age_ranges = ['18-44', '45-64', '65-74', '75+']
        for age_range in age_ranges:
            percent_change[age_range] = (data[f'{age_range} - Percentage'].iloc[-1] -
                                            data[f'{age_range} - Percentage'].iloc[0]) / \
                                           data[f'{age_range} - Percentage'].iloc[0] * 100
        return percent_change

    percent_change_before_covid = calculate_percentage_change(before_2018)
    percentage_change_after = calculate_percentage_change(after_2018)

    # Visualize percentage change for each age range
    plt.figure(figsize=(10, 6))
    plt.bar(percent_change_before_covid.keys(), percent_change_before_covid.values(), color='blue', alpha=0.7,
            label='Before COVID-19')
    plt.bar(percentage_change_after.keys(), percentage_change_after.values(), color='red', alpha=0.7,
            label='After COVID-19')
    plt.title('Percentage Change in Diabetic Cases Before and After COVID-19 by Age Range')
    plt.xlabel('Age Range')
    plt.ylabel('Percentage Change')
    plt.legend()
    plt.show()
    

    # Calculate correlation using pearson correlation technique
    correlation_before = before_2018.corr()
    correlation_after = after_2018.corr()

    # Visualize correlation matrices
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    sns.heatmap(correlation_before, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8})
    plt.title('Correlation Matrix Before COVID-19')
    plt.subplot(1, 2, 2)
    sns.heatmap(correlation_after, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8})
    plt.title('Correlation Matrix After COVID-19')
    plt.tight_layout()
    plt.show()

    # Calculate correlation difference for better understaning
    correlation_difference = correlation_after - correlation_before
    print("Correlation before covid is ",correlation_before)
    print("Correlation after covid is ", correlation_after)
    print("Correlation difference is ", correlation_difference)
    # Visualize correlation difference matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_difference, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
    plt.title('Correlation Matrix Difference: After - Before COVID-19')
    plt.tight_layout()
    plt.show()

# Process each CSV file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        file_path = os.path.join(directory, filename)
        process_csv(file_path)
        print("Processed ",filename,"Successfully")
# Out:
# Size of original Dataset of file : DiabetesAtlas_Alabama.csv is (21, 13)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 2.3                11.4                15.4
# 1  2001                 3.2                13.3                20.7
# 2  2002                 2.6                12.7                17.6
# 3  2003                 3.4                12.2                18.4
# 4  2004                 2.9                10.7                20.1
#
#    75+ - Percentage
# 0              15.5
# 1              23.8
# 2              20.1
# 3              16.4
# 4              16.7
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.748175
# 45-64 - Percentage            0.748175            1.000000
# 65-74 - Percentage            0.686488            0.857464
# 75+ - Percentage              0.501610            0.820227
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.686488          0.501610
# 45-64 - Percentage            0.857464          0.820227
# 65-74 - Percentage            1.000000          0.738395
# 75+ - Percentage              0.738395          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                 1.0
# 45-64 - Percentage                 1.0                 1.0
# 65-74 - Percentage                 1.0                 1.0
# 75+ - Percentage                   1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0               1.0
# 45-64 - Percentage                 1.0               1.0
# 65-74 - Percentage                 1.0               1.0
# 75+ - Percentage                   1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000            0.251825
# 45-64 - Percentage            0.251825            0.000000
# 65-74 - Percentage            0.313512            0.142536
# 75+ - Percentage              0.498390            0.179773
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.313512          0.498390
# 45-64 - Percentage            0.142536          0.179773
# 65-74 - Percentage            0.000000          0.261605
# 75+ - Percentage              0.261605          0.000000
# Processed  DiabetesAtlas_Alabama.csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Colorado.csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 0.9                 6.9                18.9
# 1  2001                 1.3                 6.3                10.8
# 2  2002                 1.6                 6.7                 9.8
# 3  2003                 1.6                 7.1                12.6
# 4  2004                 1.4                 6.7                10.9
#
#    75+ - Percentage
# 0              12.3
# 1              17.9
# 2              13.2
# 3              11.1
# 4              10.8
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.704514
# 45-64 - Percentage            0.704514            1.000000
# 65-74 - Percentage            0.374417            0.557253
# 75+ - Percentage              0.451942            0.548865
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.374417          0.451942
# 45-64 - Percentage            0.557253          0.548865
# 65-74 - Percentage            1.000000          0.289223
# 75+ - Percentage              0.289223          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                -1.0
# 45-64 - Percentage                -1.0                 1.0
# 65-74 - Percentage                -1.0                 1.0
# 75+ - Percentage                  -1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                -1.0              -1.0
# 45-64 - Percentage                 1.0               1.0
# 65-74 - Percentage                 1.0               1.0
# 75+ - Percentage                   1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000           -1.704514
# 45-64 - Percentage           -1.704514            0.000000
# 65-74 - Percentage           -1.374417            0.442747
# 75+ - Percentage             -1.451942            0.451135
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage           -1.374417         -1.451942
# 45-64 - Percentage            0.442747          0.451135
# 65-74 - Percentage            0.000000          0.710777
# 75+ - Percentage              0.710777          0.000000
# Processed  DiabetesAtlas_Colorado.csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Connecticut.csv is (21, 13)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 1.5                 7.2                15.6
# 1  2001                 2.0                 8.5                15.3
# 2  2002                 1.6                 7.1                15.5
# 3  2003                 1.9                 7.2                15.7
# 4  2004                 2.0                 7.2                15.0
#
#    75+ - Percentage
# 0              10.5
# 1              13.1
# 2              15.7
# 3              13.1
# 4              14.4
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.692649
# 45-64 - Percentage            0.692649            1.000000
# 65-74 - Percentage            0.595814            0.814283
# 75+ - Percentage              0.512946            0.830121
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.595814          0.512946
# 45-64 - Percentage            0.814283          0.830121
# 65-74 - Percentage            1.000000          0.729177
# 75+ - Percentage              0.729177          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                -1.0
# 45-64 - Percentage                -1.0                 1.0
# 65-74 - Percentage                 1.0                -1.0
# 75+ - Percentage                   NaN                 NaN
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0               NaN
# 45-64 - Percentage                -1.0               NaN
# 65-74 - Percentage                 1.0               NaN
# 75+ - Percentage                   NaN               NaN
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000           -1.692649
# 45-64 - Percentage           -1.692649            0.000000
# 65-74 - Percentage            0.404186           -1.814283
# 75+ - Percentage                   NaN                 NaN
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.404186               NaN
# 45-64 - Percentage           -1.814283               NaN
# 65-74 - Percentage            0.000000               NaN
# 75+ - Percentage                   NaN               NaN
# Processed  DiabetesAtlas_Connecticut.csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Florida (1).csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 1.7                 9.7                14.0
# 1  2001                 2.6                10.7                17.3
# 2  2002                 2.2                11.3                13.3
# 3  2003                 2.6                12.9                14.3
# 4  2004                 2.0                11.7                15.7
#
#    75+ - Percentage
# 0              13.9
# 1              13.0
# 2              15.0
# 3              14.0
# 4              13.5
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.311700
# 45-64 - Percentage            0.311700            1.000000
# 65-74 - Percentage            0.516225            0.681702
# 75+ - Percentage              0.380425            0.729599
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.516225          0.380425
# 45-64 - Percentage            0.681702          0.729599
# 65-74 - Percentage            1.000000          0.795562
# 75+ - Percentage              0.795562          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                -1.0
# 45-64 - Percentage                -1.0                 1.0
# 65-74 - Percentage                 1.0                -1.0
# 75+ - Percentage                  -1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0              -1.0
# 45-64 - Percentage                -1.0               1.0
# 65-74 - Percentage                 1.0              -1.0
# 75+ - Percentage                  -1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000           -1.311700
# 45-64 - Percentage           -1.311700            0.000000
# 65-74 - Percentage            0.483775           -1.681702
# 75+ - Percentage             -1.380425            0.270401
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.483775         -1.380425
# 45-64 - Percentage           -1.681702          0.270401
# 65-74 - Percentage            0.000000         -1.795562
# 75+ - Percentage             -1.795562          0.000000
# Processed  DiabetesAtlas_Florida (1).csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Louisiana (4).csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 2.3                10.3                14.6
# 1  2001                 2.6                11.4                20.1
# 2  2002                 2.9                10.5                13.6
# 3  2003                 2.7                13.1                19.8
# 4  2004                 2.4                12.5                21.4
#
#    75+ - Percentage
# 0              14.7
# 1              12.9
# 2              16.6
# 3              16.8
# 4              16.9
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.503841
# 45-64 - Percentage            0.503841            1.000000
# 65-74 - Percentage            0.437673            0.767442
# 75+ - Percentage              0.477338            0.781824
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.437673          0.477338
# 45-64 - Percentage            0.767442          0.781824
# 65-74 - Percentage            1.000000          0.817994
# 75+ - Percentage              0.817994          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                -1.0
# 45-64 - Percentage                -1.0                 1.0
# 65-74 - Percentage                 1.0                -1.0
# 75+ - Percentage                   1.0                -1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0               1.0
# 45-64 - Percentage                -1.0              -1.0
# 65-74 - Percentage                 1.0               1.0
# 75+ - Percentage                   1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000           -1.503841
# 45-64 - Percentage           -1.503841            0.000000
# 65-74 - Percentage            0.562327           -1.767442
# 75+ - Percentage              0.522662           -1.781824
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.562327          0.522662
# 45-64 - Percentage           -1.767442         -1.781824
# 65-74 - Percentage            0.000000          0.182006
# 75+ - Percentage              0.182006          0.000000
# Processed  DiabetesAtlas_Louisiana (4).csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Michigan.csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 2.2                11.0                14.5
# 1  2001                 2.4                10.5                17.0
# 2  2002                 2.2                10.6                19.2
# 3  2003                 2.7                11.7                17.3
# 4  2004                 2.5                11.5                15.6
#
#    75+ - Percentage
# 0              15.4
# 1              15.0
# 2              22.8
# 3              15.8
# 4              16.8
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.416449
# 45-64 - Percentage            0.416449            1.000000
# 65-74 - Percentage            0.353647            0.666864
# 75+ - Percentage              0.136378            0.661998
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.353647          0.136378
# 45-64 - Percentage            0.666864          0.661998
# 65-74 - Percentage            1.000000          0.640969
# 75+ - Percentage              0.640969          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                 1.0
# 45-64 - Percentage                 1.0                 1.0
# 65-74 - Percentage                -1.0                -1.0
# 75+ - Percentage                   1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                -1.0               1.0
# 45-64 - Percentage                -1.0               1.0
# 65-74 - Percentage                 1.0              -1.0
# 75+ - Percentage                  -1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000            0.583551
# 45-64 - Percentage            0.583551            0.000000
# 65-74 - Percentage           -1.353647           -1.666864
# 75+ - Percentage              0.863622            0.338002
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage           -1.353647          0.863622
# 45-64 - Percentage           -1.666864          0.338002
# 65-74 - Percentage            0.000000         -1.640969
# 75+ - Percentage             -1.640969          0.000000
# Processed  DiabetesAtlas_Michigan.csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Mississippi.csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 3.1                 9.4                18.9
# 1  2001                 3.9                13.2                20.6
# 2  2002                 2.9                12.9                18.7
# 3  2003                 4.1                16.5                23.2
# 4  2004                 3.6                13.8                22.0
#
#    75+ - Percentage
# 0              17.8
# 1              16.7
# 2              18.2
# 3              21.4
# 4              18.9
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.600199
# 45-64 - Percentage            0.600199            1.000000
# 65-74 - Percentage            0.760989            0.782557
# 75+ - Percentage              0.612886            0.756164
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.760989          0.612886
# 45-64 - Percentage            0.782557          0.756164
# 65-74 - Percentage            1.000000          0.773059
# 75+ - Percentage              0.773059          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                -1.0
# 45-64 - Percentage                -1.0                 1.0
# 65-74 - Percentage                 1.0                -1.0
# 75+ - Percentage                  -1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0              -1.0
# 45-64 - Percentage                -1.0               1.0
# 65-74 - Percentage                 1.0              -1.0
# 75+ - Percentage                  -1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000           -1.600199
# 45-64 - Percentage           -1.600199            0.000000
# 65-74 - Percentage            0.239011           -1.782557
# 75+ - Percentage             -1.612886            0.243836
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.239011         -1.612886
# 45-64 - Percentage           -1.782557          0.243836
# 65-74 - Percentage            0.000000         -1.773059
# 75+ - Percentage             -1.773059          0.000000
# Processed  DiabetesAtlas_Mississippi.csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Missouri (4).csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 1.8                 9.0                14.6
# 1  2001                 1.9                10.4                14.2
# 2  2002                 2.7                 9.9                15.9
# 3  2003                 2.0                 9.6                15.8
# 4  2004                 2.3                10.4                18.2
#
#    75+ - Percentage
# 0              17.1
# 1              10.0
# 2              15.7
# 3              15.6
# 4              13.1
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.659002
# 45-64 - Percentage            0.659002            1.000000
# 65-74 - Percentage            0.595595            0.935166
# 75+ - Percentage              0.563379            0.791646
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.595595          0.563379
# 45-64 - Percentage            0.935166          0.791646
# 65-74 - Percentage            1.000000          0.871239
# 75+ - Percentage              0.871239          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                 1.0
# 45-64 - Percentage                 1.0                 1.0
# 65-74 - Percentage                 1.0                 1.0
# 75+ - Percentage                  -1.0                -1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0              -1.0
# 45-64 - Percentage                 1.0              -1.0
# 65-74 - Percentage                 1.0              -1.0
# 75+ - Percentage                  -1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000            0.340998
# 45-64 - Percentage            0.340998            0.000000
# 65-74 - Percentage            0.404405            0.064834
# 75+ - Percentage             -1.563379           -1.791646
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.404405         -1.563379
# 45-64 - Percentage            0.064834         -1.791646
# 65-74 - Percentage            0.000000         -1.871239
# 75+ - Percentage             -1.871239          0.000000
# Processed  DiabetesAtlas_Missouri (4).csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Montana (5).csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 1.0                 5.4                15.6
# 1  2001                 1.8                 7.0                14.2
# 2  2002                 2.2                 6.9                12.0
# 3  2003                 1.7                 7.3                12.5
# 4  2004                 1.7                 8.0                13.9
#
#    75+ - Percentage
# 0              11.6
# 1              11.5
# 2              11.9
# 3              11.6
# 4              12.7
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.555315
# 45-64 - Percentage            0.555315            1.000000
# 65-74 - Percentage            0.225061            0.502262
# 75+ - Percentage              0.502286            0.817131
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.225061          0.502286
# 45-64 - Percentage            0.502262          0.817131
# 65-74 - Percentage            1.000000          0.571818
# 75+ - Percentage              0.571818          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                 1.0
# 45-64 - Percentage                 1.0                 1.0
# 65-74 - Percentage                 1.0                 1.0
# 75+ - Percentage                   1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0               1.0
# 45-64 - Percentage                 1.0               1.0
# 65-74 - Percentage                 1.0               1.0
# 75+ - Percentage                   1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000            0.444685
# 45-64 - Percentage            0.444685            0.000000
# 65-74 - Percentage            0.774939            0.497738
# 75+ - Percentage              0.497714            0.182869
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.774939          0.497714
# 45-64 - Percentage            0.497738          0.182869
# 65-74 - Percentage            0.000000          0.428182
# 75+ - Percentage              0.428182          0.000000
# Processed  DiabetesAtlas_Montana (5).csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Ohio (9).csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 2.0                 8.7                14.1
# 1  2001                 2.2                11.0                15.3
# 2  2002                 2.9                 9.4                19.5
# 3  2003                 3.2                11.0                22.1
# 4  2004                 2.9                10.2                21.6
#
#    75+ - Percentage
# 0              14.7
# 1              14.3
# 2              16.6
# 3              19.7
# 4              12.9
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.407634
# 45-64 - Percentage            0.407634            1.000000
# 65-74 - Percentage            0.601136            0.822161
# 75+ - Percentage              0.505246            0.841477
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.601136          0.505246
# 45-64 - Percentage            0.822161          0.841477
# 65-74 - Percentage            1.000000          0.834938
# 75+ - Percentage              0.834938          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                -1.0
# 45-64 - Percentage                -1.0                 1.0
# 65-74 - Percentage                -1.0                 1.0
# 75+ - Percentage                  -1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                -1.0              -1.0
# 45-64 - Percentage                 1.0               1.0
# 65-74 - Percentage                 1.0               1.0
# 75+ - Percentage                   1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000           -1.407634
# 45-64 - Percentage           -1.407634            0.000000
# 65-74 - Percentage           -1.601136            0.177839
# 75+ - Percentage             -1.505246            0.158523
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage           -1.601136         -1.505246
# 45-64 - Percentage            0.177839          0.158523
# 65-74 - Percentage            0.000000          0.165062
# 75+ - Percentage              0.165062          0.000000
# Processed  DiabetesAtlas_Ohio (9).csv Successfully
# Size of original Dataset of file : DiabetesAtlas_Pennsylvania.csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 1.9                 9.1                18.3
# 1  2001                 1.5                 9.0                13.8
# 2  2002                 2.7                 8.7                20.7
# 3  2003                 1.9                10.8                19.0
# 4  2004                 2.3                10.3                17.5
#
#    75+ - Percentage
# 0              14.5
# 1              17.7
# 2              18.3
# 3              17.9
# 4              16.2
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.398260
# 45-64 - Percentage            0.398260            1.000000
# 65-74 - Percentage            0.363793            0.676383
# 75+ - Percentage              0.545153            0.803461
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.363793          0.545153
# 45-64 - Percentage            0.676383          0.803461
# 65-74 - Percentage            1.000000          0.657694
# 75+ - Percentage              0.657694          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                 1.0
# 45-64 - Percentage                 1.0                 1.0
# 65-74 - Percentage                 1.0                 1.0
# 75+ - Percentage                   1.0                 1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                 1.0               1.0
# 45-64 - Percentage                 1.0               1.0
# 65-74 - Percentage                 1.0               1.0
# 75+ - Percentage                   1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000            0.601740
# 45-64 - Percentage            0.601740            0.000000
# 65-74 - Percentage            0.636207            0.323617
# 75+ - Percentage              0.454847            0.196539
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.636207          0.454847
# 45-64 - Percentage            0.323617          0.196539
# 65-74 - Percentage            0.000000          0.342306
# 75+ - Percentage              0.342306          0.000000
# Processed  DiabetesAtlas_Pennsylvania.csv Successfully
# Size of original Dataset of file : DiabetesAtlas_South Carolina.csv is (21, 14)
#
# Column data :
#     Year  18-44 - Percentage  45-64 - Percentage  65-74 - Percentage  \
# 0  2000                 1.9                11.8                15.5
# 1  2001                 2.7                13.2                18.1
# 2  2002                 2.9                12.1                18.6
# 3  2003                 3.1                14.6                18.3
# 4  2004                 2.5                12.1                22.2
#
#    75+ - Percentage
# 0              15.5
# 1              11.1
# 2              18.9
# 3              18.4
# 4              16.1
# Correlation before covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            1.000000            0.601242
# 45-64 - Percentage            0.601242            1.000000
# 65-74 - Percentage            0.731259            0.747512
# 75+ - Percentage              0.516877            0.785649
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage            0.731259          0.516877
# 45-64 - Percentage            0.747512          0.785649
# 65-74 - Percentage            1.000000          0.776190
# 75+ - Percentage              0.776190          1.000000
# Correlation after covid is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage                 1.0                 1.0
# 45-64 - Percentage                 1.0                 1.0
# 65-74 - Percentage                -1.0                -1.0
# 75+ - Percentage                  -1.0                -1.0
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage                -1.0              -1.0
# 45-64 - Percentage                -1.0              -1.0
# 65-74 - Percentage                 1.0               1.0
# 75+ - Percentage                   1.0               1.0
# Correlation difference is                      18-44 - Percentage  45-64 - Percentage  \
# 18-44 - Percentage            0.000000            0.398758
# 45-64 - Percentage            0.398758            0.000000
# 65-74 - Percentage           -1.731259           -1.747512
# 75+ - Percentage             -1.516877           -1.785649
#
#                     65-74 - Percentage  75+ - Percentage
# 18-44 - Percentage           -1.731259         -1.516877
# 45-64 - Percentage           -1.747512         -1.785649
# 65-74 - Percentage            0.000000          0.223810
# 75+ - Percentage              0.223810          0.000000
# Processed  DiabetesAtlas_South Carolina.csv Successfully
